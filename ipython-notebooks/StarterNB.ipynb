# %% [markdown]
# #### You can snapshot your terminal to publish and share the Notebook + Environment

# %%
#General Usefil libs

# %%
import requests
import sqlalchemy
import pylab as pylb

# %%
#Numerical libraries pre-installed

# %%
import numpy as np
import pandas as pd
import ystockquote as ys
import sklearn
import csv
import scipy

# %%
#Plotting Libraries

# %%
import matplotlib.pyplot as plt
import plotly
import pylab

# %%
#Deep learning toolkits

# %%
import neurolab 
import pybrain

# %%
## Inline Plotting Exaple

# %%
x = linspace(0, 7, 10)
y = x ** 2
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()
